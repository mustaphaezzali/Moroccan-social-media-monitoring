# %% [markdown]
# # This notebook is based on Maarten Grootendorst [BERTopic](https://github.com/MaartenGr/BERTopic/tree/v0.4.2) tutorial avalible [here](https://github.com/MaartenGr/BERTopic/blob/v0.4.2/notebooks/BERTopic.ipynb).

# %% [markdown]
# # **BERT for Arabic Topic Modeling: An Experimental Study on BERTopic Technique**
# Abeer Abuzayed and Hend Al-Khalifa
#
# # Abstract
# Topic modeling is an unsupervised machine learning technique for finding abstract topics in a large collection of documents. It
# helps in organizing, understanding and summarizing large collections of textual information and discovering the latent topics that
# vary among documents in a given corpus. Latent Dirichlet allocation (LDA) and Non-Negative Matrix Factorization (NMF) are
# two of the most popular topic modeling techniques. LDA uses a probabilistic approach whereas NMF uses matrix factorization
# approach, however, new techniques that are based on BERT for topic modeling do exist. In this paper, we aim to experiment with
# BERTopic using different Pre-Trained Arabic Language Models as embeddings, and compare its results against LDA and NMF
# techniques. We used Normalized Pointwise Mutual Information (NPMI) measure to evaluate the results of topic modeling
# techniques. The overall results generated by BERTopic showed better results compared to NMF and LDA.

# %% [markdown]
# **NOTE**: Make sure to select a GPU runtime. Otherwise, the model can take quite some time to create the document embeddings!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# we start with installing bertopic from pypi before preparing the data

# !pip install bertopic[all]
# Out:
# Collecting bertopic[all]
# WARNING: bertopic 0.14.1 does not provide the extra 'all'
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ------------------------------------ 120.7/120.7 kB 883.9 kB/s eta 0:00:00
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ---------------------------------------- 88.2/88.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=1.1.5 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from bertopic[all]) (1.5.2)
# Requirement already satisfied: tqdm>=4.41.1 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from bertopic[all]) (4.64.1)
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ---------------------------------------- 86.0/86.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: plotly>=4.7.0 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from bertopic[all]) (5.13.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from bertopic[all]) (1.2.0)
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29-cp310-cp310-win_amd64.whl (595 kB)
#      ------------------------------------ 595.9/595.9 kB 528.1 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from bertopic[all]) (1.23.5)
# Requirement already satisfied: joblib>=1.0 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from hdbscan>=0.8.29->bertopic[all]) (1.2.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from hdbscan>=0.8.29->bertopic[all]) (1.9.3)
# Collecting cython>=0.27
#   Downloading Cython-0.29.34-py2.py3-none-any.whl (988 kB)
#      ------------------------------------ 988.1/988.1 kB 773.0 kB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from pandas>=1.1.5->bertopic[all]) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from pandas>=1.1.5->bertopic[all]) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from plotly>=4.7.0->bertopic[all]) (8.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from scikit-learn>=0.22.2.post1->bertopic[all]) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 566.7 kB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic[all]) (1.13.1)
# Requirement already satisfied: torchvision in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic[all]) (0.14.1)
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 1.5 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp310-cp310-win_amd64.whl (977 kB)
#      -------------------------------------- 977.8/977.8 kB 1.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      -------------------------------------- 224.5/224.5 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from tqdm>=4.41.1->bertopic[all]) (0.4.6)
# Requirement already satisfied: numba>=0.49 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from umap-learn>=0.5.0->bertopic[all]) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 707.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (4.3.0)
# Requirement already satisfied: requests in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (2.28.1)
# Requirement already satisfied: fsspec in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (2023.1.0)
# Collecting filelock
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[all]) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[all]) (65.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic[all]) (1.16.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 3.5/3.5 MB 709.6 kB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[all]) (2022.10.31)
# Requirement already satisfied: click in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from nltk->sentence-transformers>=0.4.1->bertopic[all]) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[all]) (9.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mustapha\anaconda3\envs\renv\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[all]) (2.1.1)
# Building wheels for collected packages: sentence-transformers, umap-learn, pynndescent
#   Building wheel for sentence-transformers (setup.py): started
#   Building wheel for sentence-transformers (setup.py): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=3e159748ae5e9d5b2e3cedf03ebba4621eeead0dc5fdd952541e6697074f224e
#   Stored in directory: c:\users\mustapha\appdata\local\pip\cache\wheels\62\f2\10\1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py): started
#   Building wheel for umap-learn (setup.py): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82814 sha256=61e133067b44ad4803bdac3cb6d0013da151ccb30c4e5890be7ca79a1f69e039
#   Stored in directory: c:\users\mustapha\appdata\local\pip\cache\wheels\a0\e8\c6\a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py): started
#   Building wheel for pynndescent (setup.py): finished with status 'done'
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55622 sha256=1d919f47c59124623374f76b5e846da12dd06a04ecf1bdeb90c6e9d4a0e965a8
#   Stored in directory: c:\users\mustapha\appdata\local\pip\cache\wheels\4a\38\5d\f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, filelock, cython, nltk, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 cython-0.29.34 filelock-3.12.0 hdbscan-0.8.29 huggingface-hub-0.14.1 nltk-3.8.1 pynndescent-0.5.10 sentence-transformers-2.2.2 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.28.1 umap-learn-0.5.3

# %%
import pandas as pd
from bertopic import BERTopic
from flair.embeddings import TransformerDocumentEmbeddings
from gensim.models.coherencemodel import CoherenceModel
import gensim.corpora as corpora
from gensim.models import LdaMulticore
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %% [markdown]
# # Load Data
# For this experiment, We used [(DataSet for Arabic Classification)](https://data.mendeley.com/datasets/v524p5dhpj/2) which contains 111,728 Arabic documents written in Modern
# Standard Arabic (MSA). The dataset was collected from three Arabic online newspapers: Assabah, Hespress and
# Akhbarona. The documents in the dataset are categorized into 5 classes: sport, politics, culture, economy and diverse.
# We removed 2939 missing documents and ran the experiments with the remaining 108789 documents without any
# document labels.

# %%
# add your data path 

data=  pd.read_csv("/content/drive/MyDrive/Topic Modeling/arabic_dataset_classifiction.csv")
data.head()
# Out:
#                                                 text  targe
# 0  بين أستوديوهات ورزازات وصحراء مرزوكة وآثار ولي...      0
# 1  قررت النجمة الأمريكية أوبرا وينفري ألا يقتصر ع...      0
# 2  أخبارنا المغربية الوزاني تصوير الشملالي ألهب ا...      0
# 3  اخبارنا المغربية قال ابراهيم الراشدي محامي سعد...      0
# 4  تزال صناعة الجلود في المغرب تتبع الطريقة التقل...      0

# %%
data.shape

# %%
data=data.dropna()
data.shape

# %%
documents = data['text'].values

# %% [markdown]
# #Embedding model
# BERTopic has two default embedding models: "distilbert-base-nli-stsb-mean-tokens'' for the English language and "xlm-r-bert-base-nli-stsb-meantokens" for any language other than English, where XLM-R models support 50+ languages.
#
# Also, you can select any model from [Hugging Face](https://huggingface.co/models)  and use it instead of the preselected models by simply passing the model through
# BERTopic with embedding_model.
#
# For more deatelis check out BERTopic decomntion [here](https://maartengr.github.io/BERTopic/tutorial/embeddings/embeddings.html).

# %%
#to experiment with other BERT models simply change the model name below

arabert = TransformerDocumentEmbeddings('aubmindlab/bert-base-arabertv02')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=384.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=824793.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=2642362.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=112.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=381.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=543490667.0, style=ProgressStyle(descri…

# %% [markdown]
# # **Create Topics**

# %% [markdown]
# For BERTopic you do not need to define the number of topics in advance, however, if you want to do so simply pass the number of topics to BERTopic with nr_topics paramete.

# %%
topic_model = BERTopic(language="arabic", low_memory=True ,calculate_probabilities=False,
                     embedding_model=arabert)

# %% [markdown]
# NOTE: Calculating probabilities can slow down BERTopic significantly at large amounts of data (>100_000 documents). It is advised to turn this off if you want to speed up the model.

# %%
topics, probs = topic_model.fit_transform(documents)

# %%
#extract most frequent topics

topic_model.get_topic_freq().head(5)

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at the most frequent topic that was generated:

# %%
#show the top 10 words in topic 1

topic_model.get_topic(1)[:10]

# %% [markdown]
# # Evaluation
# To evaluate the model topics coherence we use [Gensim](https://radimrehurek.com/gensim/models/coherencemodel.html) implementation of the Normalized
# Pointwise Mutual Information (NPMI).

# %%
texts = [[word for word in str(document).split()] for document in documents]
id2word = corpora.Dictionary(texts)
corpus = [id2word.doc2bow(text) for text in texts]

# %%
topics=[]
for i in topic_model.get_topics():
  row=[]
  topic= topic_model.get_topic(i)
  for word in topic:
     row.append(word[0])
  topics.append(row)

# %%
# compute Coherence Score

cm = CoherenceModel(topics=topics, texts=texts, corpus=corpus, dictionary=id2word, coherence='c_npmi')
coherence = cm.get_coherence() 
print('\nCoherence Score: ', coherence)

# %% [markdown]
# # **Visualize Topics**
# After having trained our `BERTopic` model, we can iteratively go through perhaps a hundred topic to get a good
# understanding of the topics that were extract. However, that takes quite some time and lacks a global representation.
# Instead, we can visualize the topics that were generated in a way very similar to
# [LDAvis](https://github.com/cpsievert/LDAvis):

# %%
topic_model.visualize_topics()

# %% [markdown]
# # **Model serialization**
# The model and its internal settings can easily be saved. Note that the documents and embeddings will not be saved. However, UMAP and HDBSCAN will be saved.

# %%
# Save model
topic_model.save("my_model")

# %%
# Load model
my_model = BERTopic.load("my_model")

# %% [markdown]
# # LDA
#
# We use the [ parallelized Latent Dirichlet Allocation (LDA)](https://radimrehurek.com/gensim/models/ldamulticore.html) from Gensim.
#
# Note: for LDA you have to define topics number in advance.

# %%
#chang the number of topics here
no_topics = 5

# run LDA
lda = LdaMulticore(corpus, id2word=id2word, num_topics=no_topics)

# %%
#compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda, texts=texts, dictionary=id2word, coherence='c_npmi')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

# %% [markdown]
# #NMF
# We use Scikit-learn implementation of [NMF](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.NMF.html).
#
# Note: for NMF you have to define topics number in advance.

# %%
# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2)
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# %%
#chang the number of topics here
no_topics = 5

# run NMF
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)

# %%
topics_NMF=[]
for index, topic in enumerate(nmf.components_):
    row=[]
    for i in topic.argsort()[-10:]:
      row.append(tfidf_vectorizer.get_feature_names()[i])
    topics_NMF.append(row)

# %%
cm = CoherenceModel(topics=topics_NMF, texts=texts, corpus=corpus, dictionary=id2word, coherence='c_npmi')
coherence_nmf = cm.get_coherence()  
print('\nCoherence Score: ', coherence_nmf)

# %% [markdown]
# If you use this notebook, please cite our paper :)
#
# ```
# Abeer Abuzayed and Hend Al-Khalifa. BERT for Arabic Topic Modeling: An Experimental Study on BERTopic Technique. Arabic Computational Linguistics, Procedia Computer Science, Elsevier, (in press).
# ```
