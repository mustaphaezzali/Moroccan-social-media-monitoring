# %%
import numpy as np
import pandas as pd

# %%
#data = pd.read_csv('hespress.csv')
import json

data = []

with open('comments.json',encoding='utf-8') as f:
    for line in f:
        try:
            obj = json.loads(line)
            data.append(obj)
        except:
            continue
print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\Mustapha\Desktop\ENSIAS 2IA\S4\PFA\Moroccan-social-media-monitoring\scraping\test.ipynb Cell 2 in 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> with open('comments.json',encoding='utf-8') as f:
#       <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>     for line in f:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a>         obj = json.loads(line)
#       <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>         data.append(obj)
#      <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> print(data)
#
# File c:\Users\Mustapha\anaconda3\envs\renv\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\Mustapha\anaconda3\envs\renv\lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 1 column 691 (char 690)

# %%
data
# Out:
#                                                  Title        Date  \
# 0    اليمين المتطرف يرفض ترسيم وتدريس اللغة الأمازي...  2023-04-24
# 1    تمنارت: الثقافة الأمازيغية أصيلة في المغرب.. و...  2023-04-23
# 2             أمسية تكرّم الفنّان الرّاحل صارح إصفضاون  2023-04-16
# 3                تبعمرانت: ثقافة الأمازيغ ضحية للإجحاف  2023-04-16
# 4            "جبل الجليد" يتميز في الدراما بالأمازيغية  2023-04-15
# ..                                                 ...         ...
# 451  هيئة تراسل رؤساء الفرق البرلمانية بشأن وضعية ا...  2022-10-31
# 452  فعاليات أمازيغية تحيي ذكرى رحيل الدغرني في أفق...  2022-10-30
# 453  جمعيات أمازيغية تقاضي جماهير الرجاء بسبب "هتاف...  2022-10-28
# 454  باحثون مغاربة يدعون إلى توسيع العرض الجامعي في...  2022-10-28
# 455              منتدى دولي يناقش أمازيغية شمال المغرب  2022-10-25
#
#                                                    URL   Category
# 0    https://www.hespress.com/%d8%a7%d9%84%d9%8a%d9...  tamazight
# 1    https://www.hespress.com/%d8%aa%d9%85%d9%86%d8...  tamazight
# 2    https://www.hespress.com/%d8%a3%d9%85%d8%b3%d9...  tamazight
# 3    https://www.hespress.com/%d8%aa%d8%a8%d8%b9%d9...  tamazight
# 4    https://www.hespress.com/%d8%ac%d8%a8%d9%84-%d...  tamazight
# ..                                                 ...        ...
# 451  https://www.hespress.com/%d9%87%d9%8a%d8%a6%d8...  tamazight
# 452  https://www.hespress.com/%d9%81%d8%b9%d8%a7%d9...  tamazight
# 453  https://www.hespress.com/%d8%ac%d9%85%d8%b9%d9...  tamazight
# 454  https://www.hespress.com/%d8%a8%d8%a7%d8%ad%d8...  tamazight
# 455  https://www.hespress.com/%d9%85%d9%86%d8%aa%d8...  tamazight
#
# [456 rows x 4 columns]

# %%
import re
import datetime

# Define the Arabic and English date format strings
arabic_format = '%A %d %B %Y - %H:%M'
english_format = '%A, %B %d, %Y - %I:%M %p'

# Define the regular expression pattern for the Arabic date
pattern = r'^(\S+)\s+(\d+)\s+(\S+)\s+(\d+)\s*-\s*(\d+):(\d+)$'

# Extract the individual date components using the regular expression
match = re.match(pattern, 'الإثنين 24 أبريل 2023 - 16:00')

# Convert the month name to a number
months = {'يناير': 1, 'فبراير': 2, 'مارس': 3, 'أبريل': 4, 'مايو': 5, 'يونيو': 6, 'يوليو': 7, 'أغسطس': 8, 'سبتمبر': 9, 'أكتوبر': 10, 'نوفمبر': 11, 'ديسمبر': 12}

# Create a datetime object from the date components


def transform(arabic_date):
    match = re.match(pattern, arabic_date)
    day_name, day, month_name, year, hour, minute = match.groups()
    month = months[month_name]
    date_object = datetime.date(int(year), month, int(day))
    return date_object


for i in range(len(data)):
    try:
        data['Date'][i] = transform(data['Date'][i])
    except:
        continue

# %%
date = data['Date'][100]
for i in range(len(data)):
    print(data['Date'][i])
    try:
        if data['Date'][i] > date:
            print(data['Title'][i])
            print(data['URL'][i])
            print(data['Category'][i])
    except:
        continue
# Out:
# 2023-04-24
# اليمين المتطرف يرفض ترسيم وتدريس اللغة الأمازيغية بمدينة مليلية المحتلة
# https://www.hespress.com/%d8%a7%d9%84%d9%8a%d9%85%d9%8a%d9%86-%d8%a7%d9%84%d9%85%d8%aa%d8%b7%d8%b1%d9%81-%d9%8a%d8%b1%d9%81%d8%b6-%d8%aa%d8%b1%d8%b3%d9%8a%d9%85-%d9%88%d8%aa%d8%af%d8%b1%d9%8a%d8%b3-%d8%a7%d9%84%d9%84%d8%ba-1159268.html
# tamazight
# 2023-04-23
# تمنارت: الثقافة الأمازيغية أصيلة في المغرب.. و"بابا علي" يجذب المشاهدين
# https://www.hespress.com/%d8%aa%d9%85%d9%86%d8%a7%d8%b1%d8%aa-%d8%a7%d9%84%d8%ab%d9%82%d8%a7%d9%81%d8%a9-%d8%a7%d9%84%d8%a3%d9%85%d8%a7%d8%b2%d9%8a%d8%ba%d9%8a%d8%a9-%d8%a3%d8%b5%d9%8a%d9%84%d8%a9-%d9%81%d9%8a-%d8%a7%d9%84-1158611.html
# tamazight
# 2023-04-16
# 2023-04-16
# 2023-04-15
# 2023-04-08
# 2023-04-05
# 2023-04-03
# 2023-04-01
# 2023-03-29
# 2023-03-25
# 2023-03-23
# 2023-03-18
# nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Mustapha\Desktop\ENSIAS 2IA\S4\PFA\Moroccan-social-media-monitoring\scraping\test.ipynb Cell 6 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> for i in range(len(data)):
#       <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     print(data['Date'][i])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>     if data['Date'][i] > date:
#       <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>         print(data['Title'][i])
#       <a href='vscode-notebook-cell:/c%3A/Users/Mustapha/Desktop/ENSIAS%202IA/S4/PFA/Moroccan-social-media-monitoring/scraping/test.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>         print(data['URL'][i])
#
# TypeError: '>' not supported between instances of 'float' and 'datetime.date'
